# %%
# %sql
CREATE CATALOG sp_catalog;

# %%
# %sql
CREATE SCHEMA sp_catalog.ecomm;

# %%
# %sql
SELECT current_user();

# %%
GRANT USE CATALOG ON CATALOG sp_catalog TO `your-user@domain.com`;
GRANT USE SCHEMA, CREATE TABLE ON SCHEMA sp_catalog.ecomm TO `your-user@domain.com`;

# %%
# %sql
-- Admin runs:
GRANT READ FILES ON EXTERNAL LOCATION `sp-db26-eu-west2-test` TO `sptnk1006+db26@gmail.com`;

# %%
# %sql
CREATE TABLE sp_catalog.ecomm.sales_analytics
USING CSV
OPTIONS (header = 'true', inferSchema = 'true')
LOCATION 's3://sp-db26-eu-west2-test/E-Commerce Sales Analytics.csv';
